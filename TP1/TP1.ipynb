# %% [markdown]
# ### ENSIMAG – Grenoble INP – UGA - Academic year 2025-2026
# # Introduction to Statistical Learning and Applications ([website](https://github.com/ISLA-Grenoble/2026-main))
#
# - Pedro L. C. Rodrigues -- `pedro.rodrigues@inria.fr`
#
# - Isabella Costa Maia -- `isabella.costa-maia@grenoble-inp.fr`
#
# ***
#
# ### ⚠️ General guidelines for TPs
#
# Each team shall upload its report on [Teide](https://teide.ensimag.fr/) before the deadline indicated at the course website. Please
# **include the name of all members** of the team on top of your report.
# The report should contain graphical representations and explanatory text. For each graph, axis names should be provided as well
# as a legend when it is appropriate. Figures should be explained by a few sentences in the text. Answer to
# the questions in order and refer to the question number in your report. Computations and
# graphics have to be performed in `python`. The report should be written as a jupyter notebook. This is a file format that allows users to format documents containing text written in markdown and `python` instructions. You should include all of the `python` instructions that you have used in the document so that it may be possible to replicate your results.
#
# ***
#
# # 🖥️ TP1: Analysis of prostate cancer data
#
# A medical study done on patients with prostate cancer aims to analyze the correlation between the prostate tumor volume and a set of clinical and morphometric variables. These variables include prostate specific antigens, a biomarker for prostate cancer, and a number of clinical measures (age, prostate weight, etc). The goal of this lab is to build a regression model to predict the severity of cancer, expressed by logarithm of the tumor volume -- `lcavol` variable -- from the following predictors:
# - `lpsa`: log of a prostate specific antigen
# - `lweight`: log of prostate weight
# - `age`: age of the patient
# - `lbph`: log of benign prostatic hyperplasia amount
# - `svi`: seminal vesicle invasion
# - `lcp`: log of capsular penetration
# - `gleason`: Gleason score (score on a cancer prognosis test)
# - `pgg45`: percent of Gleason scores 4 or 5
#
# The file `prostate.data`, available [here](https://github.com/ISLA-Grenoble/2025-main/blob/main/TP/TP1/prostate.data), contains measures of the logarithm of the tumor
# volume and of the 8 predictors for 97 patients. This file also contains an additional variable, called `train`, which will
# not be used and has to be removed.

# %% [markdown]
# ## ▶️ Exercise 1: Preliminary analysis of the data (1 points)
#
# **(a)** Download the file `prostate.data` and store it in your current folder. Read the dataset in using `pandas` as per
# ```
# import pandas as pd
# df = pd.read_csv("prostate.data", sep="\t")
# ```
# check how to use function `df.drop` to remove the first and last columns of `df` containing useless tags.

# %%
import pandas as pd 
#load the dataset
filename='prostate.data'
df = pd.read_csv("prostate.data", sep="\t")
#remove train
df=df.drop(columns="train", axis='columns')
#remove first 
df = df.drop(columns=[df.columns[0]])

# %% [markdown]
# **(b)** The function defined below generates scatterplots (clouds of points) between all pairs of variables, allowing us to visually analyse the correlations between all variables in the dataframe. Explain what each line of function `pairplot` does and how it affects the final plot. You can use command `help` in the `python` shell to get the documentation of each function.

# %%
# import the main plotting library for python
import matplotlib.pyplot as plt

# make a pairplot from scratch
def pairplot(df, figsize=None):  
    if figsize is None:          # If no figure size is given
        figsize = (7.10, 6.70)   # Set a default size, which controls the global readability of the plot    
    n_vars = df.shape[1]         # Number of variables, which defines the number of rows and columns  
    fig, ax = plt.subplots(figsize=figsize, ncols=n_vars, nrows=n_vars)# Create an n_vars × n_vars grid of subplots (one plot per variable pair)
    plt.subplots_adjust(wspace=0.10, hspace=0.10, left=0.05, right=0.95, bottom=0.05, top=0.95) # Reduce spacing so subplots appear as a compact matrix
    # Loop through all variable combinations
    for i in range(n_vars):
        for j in range(n_vars):        
            axij = ax[i][j]      # Select the subplot corresponding to variables i and j        
            i_name = df.columns[i]  # Variable shown on the y-axis
            j_name = df.columns[j]  # Variable shown on the x-axis    
            axij.set_xticks([])  # Remove x-axis ticks to avoid visual clutter
            axij.set_yticks([])  # Remove y-axis ticks to keep focus on point patterns       
            axij.margins(0.1)    # Add padding so points do not touch subplot borders    
            if i != j:           # Off-diagonal plots
                axij.scatter(df[i_name], df[j_name], s=10)# Draw a scatterplot, showing the correlation between two different variables, first parameter is x-axis and second is y-axis on the scatterplot
            else: # Diagonal plots
                axij.text(0.5, 0.5, i_name, fontsize=10,# Replace scatterplots with variable names to improve matrix readability
                          horizontalalignment='center',
                          verticalalignment='center',
                          transform=axij.transAxes) 
    return fig, ax # Return objects for display 

fig, ax = pairplot(df)
plt.show()

# %% [markdown]
# **(c)** Based on the generated figure, identify which variables seem the most correlated to `lcavol`. Also, infer the datatype for each of the predictors.

# %% [markdown]
# **Answer :**
# Let's focus on the first column beacause it is symetric and it is where the `lcavol` is represented with other variable, so we can analyze which variables seems the most correlated to it.
# `lcp`, `lpsa`, and `lweight` appear to be the most strongly positively correlated with `lcavol` (with `lpsa` showing the clearest linear trend). `pgg45` shows a weaker positive association, and `svi` also appears associated with higher `lcavol` values. The relationships with `age`, `lbph`, and `gleason` are less clearly linear.
# Regarding datatypes: `lweight`, `lbph`, `lcp`,`vlpsa` and `pgg45` are quantitative continuous predictors; `age` is quantitative discrete; `svi` is binary categorical; and `gleason` is an discrete categorical predictor.

# %% [markdown]
# **(d)** Recall the formula of correlation between two vectors and implement it with `numpy`. Explain the difference of your result when compared to `df.corr()`. Change the function `pairplot`to show the correlation coefficient on the upper triangle of the subplots. (Bonus) Use locally weighted scatterplot smoothing (LOWESS) to see the trends between pairs of features with `statsmodels.nonparametric.smoothers_lowess`.

# %% [markdown]
# $$
# p(X,Y)=\frac{Cov(X,Y)}{\sqrt{Var(X)}*\sqrt{Var(Y)}}
# $$

# %% [markdown]
# It is the formula of correlation between two vectors where $p(X,Y) \in [-1,1]$

# %%
#implementation of correlation coefficient with numpy
import numpy as np 
from statsmodels.nonparametric.smoothers_lowess import lowess

def correlation(x, y):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)
    cov_xy = ((x - x.mean()) * (y - y.mean())).sum() /len(x) 
    sx = x.std()
    sy = y.std()
    return cov_xy / (sx * sy)

def show(df, figsize=None, add_lowess=True, lowess_frac=0.6, lowess_it=0, lowess_color="crimson", lowess_lw=2):
    if figsize is None:
        figsize = (7.10, 6.70)

    n_vars = df.shape[1]
    fig, ax = plt.subplots(figsize=figsize, ncols=n_vars, nrows=n_vars)
    plt.subplots_adjust(wspace=0.10, hspace=0.10, left=0.05, right=0.95, bottom=0.05, top=0.95)

    for i in range(n_vars):
        for j in range(n_vars):
            axij = ax[i][j]
            i_name = df.columns[i]
            j_name = df.columns[j]

            axij.set_xticks([])
            axij.set_yticks([])
            axij.margins(0.1)

            if j > i:
                axij.text(
                    0.5, 0.5,
                    np.round(correlation(df[i_name], df[j_name]), 2),
                    fontsize=10,
                    horizontalalignment='center',
                    verticalalignment='center',
                    transform=axij.transAxes
                )

            elif j < i:
                # Scatter
                x = df[i_name].to_numpy()
                y = df[j_name].to_numpy()
                mask = np.isfinite(x) & np.isfinite(y)
                x = x[mask]
                y = y[mask]
                axij.scatter(x, y, s=10)
                if add_lowess and len(x) >= 3:
                    smoothed = lowess(endog=y, exog=x, frac=lowess_frac, it=lowess_it, return_sorted=True)
                    axij.plot(smoothed[:, 0], smoothed[:, 1], color=lowess_color, linewidth=lowess_lw)

            else:
                axij.text(
                    0.5, 0.5,
                    i_name,
                    fontsize=10,
                    horizontalalignment='center',
                    verticalalignment='center',
                    transform=axij.transAxes
                )

    return fig, ax

fig, ax = show(df)
plt.show()

# %% [markdown]
# My NumPy implementation uses the population formulas (ddof=0, division by n), whereas **df.corr()** uses the sample convention (ddof=1, division by n-1) and also ignores missing values pairwise. If the same ddof convention is used consistently and there are no NaNs, the results should match; any discrepancy mainly comes from ddof conventions and/or pandas NaN handling

# %% [markdown]
# ## ▶️ Exercise 2: Linear regression (7 points)
#
# In this exercise, we will perform a multiple linear regression to build a predictive model for the `lcavol` variable. The variables `gleason` and `svi` should be considered as qualitative variables. You can declare them as such with :

# %%
df['svi'] = df['svi'].astype("category")
df['gleason'] = df['gleason'].astype("category")

# %% [markdown]
# **(a)** Provide the mathematical equation of the regression model (note that you can use LaTeX to write equations) and define the diﬀerent parameters.

# %% [markdown]
# We can write the mathematical equation of the regression model in the following way :
#
# $$
# \begin{aligned}
# \text{lcavol} &= \beta_0 + \beta_1 X_1 + ... + \beta_p X_p + \epsilon \\
# &= \beta_0 + \beta_1 X_\text{lpsa} + \beta_2 X_\text{lweight} + \beta_3 X_\text{age} + \beta_4 X_\text{lbph} + \beta_5 X_\text{lcp} + \beta_6 X_\text{pgg45} + \beta_{S1} X_{\text{svi}=1} + \beta_{G7} X_{\text{gleason}=7} + \beta_{G8} X_{\text{gleason}=8} + \beta_{G9} X_{\text{gleason}=9} + \epsilon
# \end{aligned}
# $$
#
# Where :
# * $\beta_0$ is the intercept (interpreted as $\beta_0 = E_{Y|X} [Y|X_1 = ... = X_p = 0])$
# * $\beta_1, ... , \beta_6$ are the coefficients associated to the variables : they represent the average effect on Y of an unit increase in $X_i$ while holding the other predictors fixed
# * $\beta_{S1}$ is the coefficient associated to `svi` when $\text{svi} = 1$. Since `svi` is a qualitative variable, we picked $\text{svi} = 0$ as our reference. $\beta_{S1}$ corresponds to the expected difference for `lcavol` when $\text{svi}=0$ compared to when $\text{svi}=1$
# * $\beta_{Gk}$ are the coefficients associated to `gleason` depending on the category. It's the same principle as `svi`, except this time there are several categories and we chose the reference $\text{gleason}=6$
# * $\epsilon$ is a zero-mean random error term, independant of $X_1, ..., X_p$

# %% [markdown]
# **(b)** Before doing the linear regression of this TP, you will first have to handle the one-hot encoding of the categorical features of the dataframe. One way of doing this is as follows:

# %%
# encode the categorical features with dummy variables
df_enc = pd.get_dummies(df, dtype=np.float64)
# to drop one dummy column for each predictor
df_enc = df_enc.drop(columns=['svi_0','gleason_6'])
# add a column of ones to the dataframe
df_enc['intercept'] = 1
# extract the dataframe for predictors
X = df_enc.drop(columns=['lcavol'])
# get the observed values to predict
y = df['lcavol']

# %% [markdown]
# - Why did we fix a `dtype` in `pd.get_dummies`?
#
#   **Answer :** The goal is to force the data type of the created columns. This makes it easier to perform calculations on matrices.
# - Why did we drop two columns after the encoding?
#
#   **Answer :** These two columns are the reference categories for the categorical variables. If we kept them, there would be linear dependence between the columns, and the matrix would not be reversible .
# - Why did we add a column of ones to the dataframe?
#
#   **Answer :** This column allows us to include the coefficient $\beta_0$ (the intercept) in our model.

# %% [markdown]
# **(c)** We will use the [`statsmodels`](https://www.statsmodels.org/) package to estimate the coefficients of the multiple linear regression as per:
#
# ```
# # import required package
# import statsmodels.api as sm
# # this line does not fit the regression model per se but only builds it
# model = sm.OLS(y, X)
# # now we actually fit the model, e.g. calculate all of regression parameters
# results = model.fit()
# ```
# Use command `results.sumary()` to get the statistical summary of the estimated coefficients.

# %%
# import required package
import statsmodels.api as sm
# this line does not fit the regression model per se but only builds it
model = sm.OLS(y, X)
# now we actually fit the model, e.g. calculate all of regression parameters
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 lcavol   R-squared:                       0.686
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     18.83
# Date:                Mon, 23 Feb 2026   Prob (F-statistic):           9.05e-18
# Time:                        16:42:37   Log-Likelihood:                -96.825
# No. Observations:                  97   AIC:                             215.7
# Df Residuals:                      86   BIC:                             244.0
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lweight       -0.0112      0.211     -0.053      0.958      -0.432       0.409
# ...

# %% [markdown]
# - Explain to what correspond the regression coeﬃcients for the lines related to `svi` and `gleason`.
#
#     **Answer :** `svi` and `gleason` are categorical variables transformed into indicator functions by the one-hot encoding.
#     The coefficient $\beta_{S1}$ related to `svi_1` represents the mean variation caused by a switch from $\text{svi} = 0$ to $\text{svi} = 1$ when all the other variables are constant (lweight, age, gleason,...).
#     Concerning `gleason` it is the same idea, except we don't compare the categories between each other. Indeed, the coefficients, $\beta_{G7}$ or $\beta_{G8}$ or $\beta_{G9}$, give the mean variation by passing from the categorical reference $\text{gleason} = 6$ to the one we are dealing with.
#
# - What would have happened in the regression if we did not do the one-hot encoding from above?
#
#    **Answer :** If we don't use the coding method on `svi` and `gleason`, there would be two differents effects.
#     First, the data from `svi` is an indicator function. So, there is no need to do the one-hot on this variable (the coeficient related to `svi` will be deleted when there is a changement of category). In that case in the summary, there will only be `svi` instead of `svi_1`.
#     Secondly, for the `gleason` variable, the effect is quite different if we don't use the coding style. Indeed, our data is integer so the linear regression would have treated it as a quantitative variable. So, the linear regression model will not fit with our theorical model and that way the result will be really different.
#
# - Comment the overall results of the regression as well.
#
#   **Answer :**
#     First, at the 5% significance level, the most robust variables are `lpsa` *(coef = 0.5496, p < 0.001)* and  `lcp` *(coef = 0.4028, p < 0.001)*, showing a clear positive effect.
#
#     The variables `age` *(coef = 0.0248, p = 0.03)* and `pgg45` *(coef = -0.0094, p = 0.04)* have a boderline significant effect. In contrast, `gleason_7` *(coef = 0.3117, p = 0.151)*,`gleason_8` *(coef = -0.7106, p = 0.352)*,`gleason_9` *(coef = 0.7901, p = 0.109)*, `svi_1` *(coef = -0.2204 , p = 0.392)* and `lweight` *(coef=-0.0112 , p=0.958)* are not statistically significant in this model.
#
#     Finally, `lbph` *(coef=-0.1042, p=0.077)* is not significant at the 5% level, but close to, suggesting a possible weak effect.
#
#     The overall model is highly significant *(F-statistic = 18.83, Prob(F) = 9.05e-18)*. This indicates that the model provides strong evidence against the null hypothesis that all coefficients are zero.
#     To sum up, the linear regression results suggest that the model is globally significant and that several predictors have a meaningful impact on the response variable.

# %% [markdown]
# **(d)** Use `results.conf_int` to get confidence intervals of level 95% for all the coeﬃcients of the predictors. Comment the results.

# %%
print(results.conf_int(0.05))
# Out:
#                   0         1
# lweight   -0.431600  0.409107
# age        0.002436  0.047129
# lbph      -0.219914  0.011515
# lcp        0.233639  0.571880
# pgg45     -0.018469 -0.000419
# lpsa       0.370474  0.728673
# svi_1     -0.730029  0.289190
# gleason_7 -0.116263  0.739616
# gleason_8 -2.219087  0.797911
# gleason_9 -0.179004  1.759273
# intercept -3.145013  0.331705

# %% [markdown]
# **Answer :** We observe that only a few intervals are entirely positive or negative, notably for `age` : $[0.002436 , 0.047129]$, `lcp` : $[0.233639 , 0.571880]$, `pgg45` : $[-0.018469,-0.000419]$ and `lpsa` : $[0.370474 , 0.728673]$. Since these intervals do not include 0, this indicates that their coefficients are significantly positive at the 5% level. In other words, we can be 95% confident that these variables have a true effect on the response variable.
# In contrast, the confidence intervals for `lweight`, `lbph`, `svi_1`, `gleason_7`, `gleason_8`, `gleason_9`, and the `intercept` all include 0. This means that, at the 5% significance level, we cannot rule out the possibility that their true effect is zero. Therefore, these predictors are not statistically significant in this model.

# %% [markdown]
# **(e)** What can you say about the eﬀects of the `lpsa` variable? Relate your answer to the $p$-value of a hypothesis test and a confidence interval. You can use `results.pvalues`.

# %%
print(results.pvalues)
# Out:
# lweight      9.577075e-01
# age          3.014993e-02
# lbph         7.695609e-02
# lcp          8.577858e-06
# pgg45        4.047741e-02
# lpsa         2.939241e-08
# svi_1        3.922717e-01
# gleason_7    1.512950e-01
# gleason_8    3.516744e-01
# gleason_9    1.087313e-01
# intercept    1.113676e-01
# dtype: float64

# %% [markdown]
# **Answer :** As we said previously, the `lspa` variable seem to have a positive effect on `lcavol`. Indeed, we can be really confident due to the p-value (p=2.939241e-08) related to the null hypothesis ' the coefficient $\beta_{lpsa}=0$ ' and the interval where $\beta_{lpsa} \in [0.370474 , 0.728673]$ at the 5% significant which do not include 0.
# So, in our model of linear regression '**(a)**', we can accept statistically that `lspa` affect `lcavol`.

# %% [markdown]
# **(f)** Implement yourself a function that calculates the values of the parameters and their corresponding $p$-values. Bonus: explain why `numpy.linalg.inv` is not necessarily the best choice for estimating the parameters as compared to `numpy.linalg.solve`.

# %%
from scipy import stats

def calculCoefficients(X,y):
    """
    Function that calculate beta hat 
    """
    XtX = X.T @ X
    Xty = X.T @ y
    beta_hat = np.linalg.inv(XtX) @ Xty
    return beta_hat


def calculPValue(X, y, beta_hat):
    r = y - X @ beta_hat
    N = len(y)
    K = X.shape[1]              
    var = (r.T @ r) / (N - K)  
    M = np.linalg.inv(X.T @ X)
    pvalue=[]
    for i in range(len(beta_hat)):
        s = np.sqrt(var * M[i, i])     
        t=beta_hat[i] / s
        pvalue.append (2 * (1 - stats.t.cdf(np.abs(t), N-K)))
    return pvalue
        
    
beta_hat=calculCoefficients(X,y)
pvalue = calculPValue(X,y,beta_hat)

n_vars = df_enc.shape[1]
for i in range(n_vars-1):
    print("------------------")
    print(df_enc.columns[i+1]," coefficient :",beta_hat[i])
    print(df_enc.columns[i+1]," p-value :",pvalue[i])
# Out:
# ------------------
# lweight  coefficient : -0.011246199275582569
# lweight  p-value : 0.9577074892464412
# ------------------
# age  coefficient : 0.024782414427470867
# age  p-value : 0.030149928042139562
# ------------------
# lbph  coefficient : -0.10419954235704765
# lbph  p-value : 0.07695608793735653
# ------------------
# lcp  coefficient : 0.40275961581195663
# lcp  p-value : 8.57785823571433e-06
# ------------------
# pgg45  coefficient : -0.009443834933542158
# pgg45  p-value : 0.040477406765621504
# ------------------
# lpsa  coefficient : 0.5495731003742201
# lpsa  p-value : 2.9392406508677027e-08
# ------------------
# svi_1  coefficient : -0.22041936486769664
# svi_1  p-value : 0.39227169442045806
# ------------------
# gleason_7  coefficient : 0.3116761867677247
# gleason_7  p-value : 0.15129499053108209
# ------------------
# gleason_8  coefficient : -0.7105882154496435
# gleason_8  p-value : 0.35167444824174954
# ------------------
# ...

# %% [markdown]
# **Answer Bonus** : `numpy.linalg.inv` is not necessarily the best choice for estimating the parameters as compared to `numpy.linalg.solve` because the second method is faster and numerically more stable because it did not compute explicitly the inverse of the matrix (computing the system of equations directly), which can lead to numerical instability and increased computational cost, especially for large matrices. It uses a LU decomposition, which is more efficient.

# %% [markdown]
# **(g)** Plot the predicted values of `lcavol` as a function of the actual values. For this, you can can use `results.get_prediction` to get predictions over `X` and then get its `predicted_mean` attribute.

# %%
pred = results.get_prediction(X)
y_hat = pred.predicted_mean 
plt.figure(figsize=(6, 6))
plt.scatter(y, y_hat, alpha=0.5)
plt.plot([y.min(), y.max()],
         [y.min(), y.max()],
         color="red", linewidth=2, label="Ideal: ŷ = y")
plt.xlabel("Actual lcavol")
plt.ylabel("Predicted lcavol")
plt.title("Predicted vs Actual lcavol")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Description :** The goal of the plot is to observe if our predicted values fit with the real one. if it the case, all the points would be on the red line. As we can see, they are quite far from the red line. We can wondering if the error made by the prediction follows a normal law of probabilty, in order to know if it is what we supposed in our theorical model '**(a)**'

# %% [markdown]
# **(h)** Plot the histogram of residuals as well as their qq-plot using `statsmodels` function `qqplot`. Can we admit that the residuals are normally distributed? Compute the residual sum of squares (RSS).

# %%
residuals = results.resid  
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(residuals, bins=20, edgecolor="black", alpha=0.5)
axes[0].set_title("Histogram of residuals")
axes[0].set_xlabel("Residual")
axes[0].set_ylabel("Frequency")
axes[0].grid(True, alpha=0.3)
sm.qqplot(residuals, line="45", ax=axes[1])
axes[1].set_title("QQ-plot of residuals")

plt.tight_layout()
plt.show()

def rss(y_real,y_predicted):
    rss=0
    for i in range(len(y_real)):
        rss+= (y_real[i] - y_predicted[i])**2
    return rss
    
print("Residual sum of squares :",rss(y,y_hat))
# Out:
# Residual sum of squares : 41.814068608045346

# %% [markdown]
# **Description :** The first plot is the hitsogram of the residual, it seems to follow a normal law of probability. To be confident on this hypothesis, we use the QQ-plot beacause it comparing two probability distributions by plotting their quantiles against each other. If the two law are the same, the points would be on the red line. We can observe that it is the case, so we might accept that the residual follow a  normal law of probability which it is what we supposed in **(a)**.

# %% [markdown]
# **(i)** What happens if predictors `lpsa` and `lcp` are removed from the multiple linear regression model? Note that you can pass a list of strings to `df.columns.drop` method.

# %%
#delete column 
df=df.drop(columns=["lpsa","lcp"], axis='columns')
#build the model 
df_enc = pd.get_dummies(df, dtype=np.float64)
df_enc = df_enc.drop(columns=['svi_0','gleason_6'])
df_enc['intercept'] = 1
X = df_enc.drop(columns=['lcavol'])
y = df['lcavol']
#perform the model 
model = sm.OLS(y, X)
results = model.fit()
#result
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 lcavol   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     8.390
# Date:                Mon, 23 Feb 2026   Prob (F-statistic):           2.11e-08
# Time:                        16:51:10   Log-Likelihood:                -125.58
# No. Observations:                  97   AIC:                             269.2
# Df Residuals:                      88   BIC:                             292.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lweight        0.5850      0.259      2.257      0.026       0.070       1.100
# ...

# %% [markdown]
# **Answer :**
# The goal of this question is to modify the previous linear regression model by deleting the variables that were the most statistically significant.
#
# In this new model, we can observe that the most significant variables are completely different. Indeed, the most robust variables are `svi_1` (coef = 1.0246, p < 0.001) and `gleason_7` (coef = 0.8007, p < 0.005), which was not the case in the previous model for these variables: `gleason_7` (coef = 0.3117, p = 0.151) and `svi_1` (coef = -0.2204, p = 0.392). On the other hand, variables that were previously significant, such as `age` (coef = 0.0248, p = 0.03), now show completely different results: `age` (coef = 0.0073, p = 0.621). Overall, there are many differences in the results between these two models.
#
# This observation highlights the importance of model specification, removing certain variables can substantially affect the estimated coefficients and their statistical significance. Therefore, careful variable selection is crucial when building a regression model, as the inclusion or exclusion of specific predictors can significantly influence the interpretation of the results.

# %% [markdown]
# ## ▶️ Exercise 3: Best subset selection (5 points)
#
# A regression model that uses $k$ predictors is said to be of size $k$. For instance,
#
# $$
# \texttt{lcavol} = \beta_1 \texttt{lpsa} + \beta_0 + \varepsilon \quad \text{and} \quad \texttt{lcavol} = \beta_1 \texttt{lweight} + \beta_0 + \varepsilon
# $$
#
# are models of size one. The regression model without any predictor $\texttt{lcavol} = \beta_0 + \varepsilon$ is a model of size 0.
#
# The goal of this exercise is to select the best model of size $k$ for each $k \in \{0, \dots, 8\}$.
#
# **(a)** Compute the residual sums of squares (RSS) for all models of size $k = 2$. Which model has the smallest RSS? Note that you can use a generator [`itertools.combination`](https://docs.python.org/3/library/itertools.html#itertools.combinations) to automatize for you all the combinations of $k$ elements among $n$.
#
# **(b)** For each value of $k \in \{0, \dots, 8\}$, select the set of predictors that minimizes the RSS. Plot these values as a function of $k$. Provide the names of the selected predictors for each value of $k$.
#
# **(c)** Do you think that minimizing the residual sum of squares is well suited to select the optimal size for the regression models? Justify your answer using what you've learned in class.

# %%
from itertools import combinations

# reload the data because the question (i) changes df

df = pd.read_csv("prostate.data", sep="\t")
df=df.drop(columns="train", axis='columns')
df = df.drop(columns=[df.columns[0]])

df['svi'] = df['svi'].astype("category")
df['gleason'] = df['gleason'].astype("category")

df_enc = pd.get_dummies(df, dtype=np.float64)
df_enc = df_enc.drop(columns=['svi_0','gleason_6'])
df_enc['intercept'] = 1
X = df_enc.drop(columns=['lcavol'])
y = df['lcavol']


predictor_groups = {
    'lpsa':    ['lpsa'],
    'lweight': ['lweight'],
    'age':     ['age'],
    'lbph':    ['lbph'],
    'svi':     ['svi_1'],
    'lcp':     ['lcp'],
    'gleason': ['gleason_7', 'gleason_8', 'gleason_9'],
    'pgg45':   ['pgg45'],
}

group_names = list(predictor_groups.keys())

model_small_rss_tab = []
for k in range(0, 9):
    best_rss = np.inf
    best_combo = None
    for combo in combinations(group_names, k):
        cols = []
        for name in combo:
            cols.extend(predictor_groups[name])
        X_sub = X[cols + ['intercept']]
        beta = calculCoefficients(X_sub, y)
        RSS = rss(y, X_sub @ beta)
        if RSS < best_rss:
            best_rss = RSS
            best_combo = combo
    model_small_rss_tab.append((best_combo, best_rss))
    print(f"Size {k}: predictors={best_combo}, RSS={best_rss:.4f}")

rss_values = []
for val in model_small_rss_tab:
    rss_values.append(val[1])

plt.plot(rss_values)
plt.xlabel("Number of predictors")
plt.ylabel("RSS")
plt.title("RSS of the best model for each number of predictors")
plt.grid(True)
plt.show()
# Out:
# Size 0: predictors=(), RSS=133.3590
# Size 1: predictors=('lpsa',), RSS=61.4209
# Size 2: predictors=('lpsa', 'lcp'), RSS=47.2781
# Size 3: predictors=('lpsa', 'age', 'lcp'), RSS=46.2378
# Size 4: predictors=('lpsa', 'age', 'lbph', 'lcp'), RSS=44.8784
# Size 5: predictors=('lpsa', 'age', 'lcp', 'gleason', 'pgg45'), RSS=43.6900
# Size 6: predictors=('lpsa', 'age', 'lbph', 'lcp', 'gleason', 'pgg45'), RSS=42.1739
# Size 7: predictors=('lpsa', 'age', 'lbph', 'svi', 'lcp', 'gleason', 'pgg45'), RSS=41.8154
# Size 8: predictors=('lpsa', 'lweight', 'age', 'lbph', 'svi', 'lcp', 'gleason', 'pgg45'), RSS=41.8141

# %% [markdown]
# ### Answer:
#
# **(c)** Minimizing the residual sum of squares (RSS) alone is not the best criterion for selecting the optimal size of regression models. While a lower RSS indicates a better fit to the training data, it does not account for model complexity. As we increase the number of predictors, we can always reduce the RSS, but this may lead to overfitting, where the model captures noise in the training data rather than the underlying relationship.
# To address this issue, we can use criteria that penalize model complexity, such as cross-validation error.

# %% [markdown]
# ## ▶️ Exercise 4: Split-validation (5 points)
#
# You have now found the best model for each of the nine possible model sizes. In the following, we wish to compare these nine diﬀerent regression models.
#
# **(a)** Give a brief overview of split-validation: how it works? Why it is not subject to the same issues raised in
# the item (c) of the previous Exercise?
#
# **Answer :** The split validation consists of splitting the observations into 2 groups : a training set and a test set. The training set is used to fit the predictive model, that will then be tested on the test set. This prevents the problem of overfitting that can be caused by only using the RSS. Indeed, the split validation tests the model on data it has not seen before (the test set), and therefore, if the data is overfitted on the training set, it will not pass the tests. The split validation method allows the model to stay more general.
#
# **(b)** Use function `train_test_split` from the `sklearn` package to split the dataset into a training and a validation (or test) partition. You can set `test_size=0.3`. For each of the nine models from before (i.e. those that minimized the RSS for each size $k$), compute the mean prediction error calculated over the samples from the test set and compare it to its corresponding mean training error. Plot a curve for each of these error as a function of size $k$.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3)

train_errors = []
test_errors = []

for k in range(0, 9):
    # We keep only the right variables
    col_to_keep = list(model_small_rss_tab[k][0]) + ['intercept']
    X_train_rss = X_train[col_to_keep]
    X_test_rss = X_test[col_to_keep]

    # Fitting of the model
    lm = LinearRegression(fit_intercept=False)
    lm.fit(X_train_rss, y_train)

    # Calculation of mean error
    y_train_pred = lm.predict(X_train_rss)
    y_test_pred = lm.predict(X_test_rss)

    err_train = mean_squared_error(y_train, y_train_pred)
    err_test = mean_squared_error(y_test, y_test_pred)
    
    train_errors.append(err_train)
    test_errors.append(err_test)

# Plot
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(range(9), rss_values)
axes[1].plot(range(9), test_errors)
axes[0].set_xlabel('nb of predictors')
axes[0].set_ylabel('Mean Prediction Error')
axes[1].set_xlabel('nb of predictors')
axes[1].set_ylabel('Mean Prediction Error')
axes[0].set_title('Model with RSS')
axes[1].set_title('Model with split-validation')
plt.show()

# %% [markdown]
# **Description :** We can see that the error for the model with RSS goes down continuously as the number of predictors grows. This confirms the fact that this model is victim if the overfitting problem. If we compare to the model with split validation, we can see a big drop of the error until 2 predictors, and then the curve goes slighlty up and down. This means that there seems to be no problem of overfitting and that after 2 predictors, the results of the prediction will not be very different.

# %% [markdown]
# **(c)** Based on the previous results, choose the best model for this dataset, giving the parameter estimates for the model trained on the whole dataset (i.e. without splitting), and explain your choice.
#
# **Answer :** We choose the following model. For the number of predictors, we chose to trust the model with split-validation, since there is no overfitting problem. For the variables used, we chose to select the ones minimizing the RSS (from exercise 3), since once the number of predictors is fixed, the RSS becomes a reliable indicator.

# %%
# Find the k that minimises the error and select the corresponding variables
k_opti = np.argmin(test_errors)
col_to_keep_whole = list(model_small_rss_tab[k_opti][0]) + ['intercept']
X_opti = X[col_to_keep_whole]

print(f"Size of model : {k_opti}")
print(f"Variables used : {model_small_rss_tab[k_opti][0]}")

# Fitting of the model
lm_whole = LinearRegression(fit_intercept=False)
lm_whole.fit(X_opti, y)

# Parameter estimates
print("--- Parameter estimates ---")
for feature, coef in zip(col_to_keep_whole, lm_whole.coef_):
    print(f"{feature} : {round(coef,5)}")

# %% [markdown]
# **(d)** What is the main limitation of split-validation ? Illustrate this issue on the cancer dataset. What could
# you do to address this problem? Code such alternative method and comment the result. Note that `sklearn` can provide you with many choices. See [here](https://scikit-learn.org/stable/model_selection.html) for more information.
#
# **Answer :** The main limitation of split-validation is that when we do the splitting, it is done randomly so the results may vary according to the different splits that can be done. The problem we also have with this dataset is that there are not a lot of observations (only 97), so this means that the model is trained and tested on even fewer observations (since we split the dataset). This makes the prediction less reliable and more likely to be disrupted by atypical observations.

# %%
# Let's do a simulation of 10 different random splittings
print("Optimal number of predictors chosen :")

for rand in range(10): 
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=rand)
    
    test_errors_list = []
    
    for k in range(0, 9):
        col_to_keep = list(model_small_rss_tab[k][0]) + ['intercept']
        
        X_train_rss = X_train[col_to_keep]
        X_test_rss = X_test[col_to_keep]
        
        lm = LinearRegression(fit_intercept=False)
        lm.fit(X_train_rss, y_train)
        
        y_test_pred = lm.predict(X_test_rss)
        test_errors_list.append(mean_squared_error(y_test, y_test_pred))
        
    # We keep the optimal number of predictors chosen with this splitting
    print(f"Random splitting {rand} : {np.argmin(test_errors_list)}")

# %% [markdown]
# **Desciption :** We can see that the optimal number of predictors chosen by the split-validation method completely varies when we do the random splitting differently. This shows that the split-validation method is not perfectly reliable. To avoid this problem, we can use the K-Fold cross-validation method. Indeed, it splits the model in several pieces, and then does the same thing as the split-validation method but choses one test group each time and the others are used as train group, so that we can have a mean of the error in the end to have a more reliable result.

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=5)
cv_errors = []

for k in range(0, 9):
    # We select the columns to keep
    col_to_keep = list(model_small_rss_tab[k][0]) + ['intercept']
    X_rss = X[col_to_keep]
    
    # We build the model
    lm = LinearRegression(fit_intercept=False)
    
    # We calculate the error with cross validation
    cv_err = []
    for idx_train, idx_test in kf.split(X_rss):
        X_train, y_train = X_rss.iloc[idx_train], y.iloc[idx_train]
        X_test, y_test = X_rss.iloc[idx_test], y.iloc[idx_test]
        lm.fit(X_train, y_train)
        y_pred = lm.predict(X_test)
        cv_err.append(mean_squared_error(y_test, y_pred))
        
    cv_errors.append(np.mean(cv_err))

    print(f"Size {k} | Mean CV Error : {round(np.mean(cv_err),5)}")

# Plot to compare the reliability
plt.figure(figsize=(8, 5))
plt.plot(range(9), cv_errors, label='5-Fold CV Error', color='blue')
plt.plot(range(9), test_errors, label='Split-validation Error', color='red')
plt.xlabel('nb of predictors')
plt.ylabel('Mean Prediction Error (MSE)')
plt.title('Comparison : Split-Validation vs Cross-Validation')
plt.legend()
plt.show()

# %% [markdown]
# **Description :** With the 5-Fold cross-validation method, the optimal number of predictors seems to be 7. If we compare the two graphs, the mean-squared error is similar with both methods. We can observe that the curve for the cross-validation method is more linear than the one for split-validation.

# %% [markdown]
# ## ▶️ Exercise 5: Conclusion (2 points)
#
# What is your conclusion about the choice of the best model to predict `lcavol` ? Comment your results.
